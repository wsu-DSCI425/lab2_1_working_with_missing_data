# %%
# All imports go here

# %% [markdown]
# # Lab 2.1 - Working with Missing Data
#
# In this lab, we will practice working with `sklearn` pipelines while also working with missing data in both the target and features.

# %% [markdown]
# ## Problem 1 - Visualize the relationships.
#
# **Tasks.**
#
# 1. Load the data in JMP.
# 2. Make a column called `Ozone missing` that uses a formula to determine when/if the target column is missing.
# 3. Open Graph Builder and add a *Local Data Filter* that filters out cases with a missing target (Ozone).
# 4. Visualize the relationships using a smoother and comment on any non-linearity.

# %% [markdown]
# *Paste a screenshot here*
#
# <font color="orange">
# Write a summary of what you learned.
# </font>

# %% [markdown]
# ## Problem 2 - Load and split up the data.
#
# 1. Load the `airquality.csv` file using `polars`.  Drop the `rownames` column, as it has not predictive value.
# 2. Split the file into two parts, one for rows with a missing Ozone target and the other for the remaining rows.

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 3 - Explore missing values in the features.
#
# Now use `get_column` with `unique` to determine which features contain missing values.

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 4 - Build your preprocessor
#
# 1. Use `make_pipeline` to make pipelines for each column type (e.g., missing data, missing data + non-linear, etc.).  Note that we want to scale all numeric columns, regardless of the type.
# 2. Use `make_column_transformer` to combine your pipelines based on the column type.

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 5 - Make models
#
# Suppose that we want to use two learning methods, OLS and kNN, to make predictions.
#
# **Task.**
# 1. Make a model object for each learning method.
# 2. Explore the parameters for each and create a grid of potential parameters.
# 3. Create a grid search object for each learning method

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 6 - Perform the grid search and compare the learning methods.
#
# Now perform the grid search for each learning method and compare the CV MSE to determine which model performed the best.

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 7 - Use the winning model to fill in the missing target values
#
# Finally, use the winning model to predict the missing values for the target (Ozone).

# %%
# Your code here (add cells as needed)
